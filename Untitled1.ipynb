# %% [markdown]
# <a href="https://colab.research.google.com/github/tanakakao/test/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import cv2

import tensorflow as tf
import tensorflow.keras as keras
from keras.layers import Dense, Dropout, Activation, Flatten, Input
from keras.optimizers import SGD
from keras import models, optimizers, layers
from keras.models import Model, Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.preprocessing.image import array_to_img, img_to_array, load_img

from keras import backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# クラス数
num_class = 2

# データ格納先（クラスごとに分けられたフォルダがあること）
dir = "/content/drive/MyDrive/image_demo"

# 画像のリサイズ
image_size = 224

# 水増し
aug = False

# ステップ数の増加率（水増し時）
steps_rate = 1

# エポック数
epochs = 150

# バッチサイズ
batch_size = 32

# 使用モデル
BASE_MODEL='VGG16'

# 転移学習
transfer_learning = False

# 最適化手法
optim = "SGD"

# 早期終了
early_stop = False
patience = 10

# 学習率の更新
# 評価値の改善が止まった時に学習率を減らします．
reduce_rl = False

# 重みの保存
checkpoint = False

# %%
classes = os.listdir(dir)
if len(classes) != num_class:
    num_class = len(classes)

input_shape = (image_size, image_size, 3)

x = []
y = []

for idx, cls in enumerate(classes):
    print(cls)
    file_lists = glob.glob(os.path.join(dir, classes[idx]) + "/*.png")
    for file in file_lists:
        image = Image.open(file)
        image = image.convert("RGB")    
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        x.append(data)
        y.append(idx)

x = np.array(x)
y = np.array(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=123)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

y_train = keras.utils.to_categorical(y_train, num_class)
y_test = keras.utils.to_categorical(y_test, num_class)

steps_per_epoch = np.ceil(len(x_train)/batch_size * steps_rate)
# Out:
# ok
# ng

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range = 0.2,
    channel_shift_range = 0.2,
    horizontal_flip=True,
)
datagen.fit(x_train)

# %%
if BASE_MODEL=='VGG16':
    from keras.applications.vgg16 import VGG16 as PTModel
elif BASE_MODEL=='ResNet50V2':
    from keras.applications.resnet_v2 import ResNet101V2 as PTModel
elif BASE_MODEL=='InceptionV3':
    from keras.applications.inception_v3 import InceptionV3 as PTModel
elif BASE_MODEL=='InceptionResNetV2':
    from keras.applications.inception_resnet_v2 import InceptionResNetV2 as PTModel
elif BASE_MODEL=='Xception':
    from keras.applications.xception import Xception as PTModel
elif BASE_MODEL=='NASNetLarge': 
    from keras.applications.nasnet import NASNetLarge as PTModel
elif BASE_MODEL=='DenseNet121':
    from keras.applications.densenet import DenseNet121 as PTModel
elif BASE_MODEL=='DenseNet201':
    from keras.applications.densenet import DenseNet201 as PTModel
elif BASE_MODEL=='MobileNetV2':
    from keras.applications.mobilenet_v2 import MobileNetV2 as PTModel
else:
    raise ValueError('Unknown model: {}'.format(BASE_MODEL))

# %%
input_tensor = Input(shape=(input_shape))

if transfer_learning == False:
    base_model = PTModel(include_top=False,input_tensor=input_tensor)
else:
    base_model = PTModel(weights='imagenet', include_top=False,input_tensor=input_tensor)

# %%
last = base_model.output
x = Flatten()(last)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)

# %%
prediction = Dense(num_class, activation='sigmoid')(x)
model = Model(inputs=base_model.input, outputs=prediction)

if transfer_learning == True:
    for layer in base_model.layers:
        layer.trainable = False
    print("Transfer learnig with", BASE_MODEL)

# %%
if optim=='SGD':
    from keras.optimizers import SGD
    optimizer = SGD(learning_rate=1e-4, momentum=0.9)
elif optim=='Adagrad':
    from keras.optimizers import Adagrad
    optimizer = Adagrad(learning_rate=1e-4)
elif optim=='RMSprop':
    from keras.optimizers import RMSprop
    optimizer = RMSprop(learning_rate=1e-4, rho=0.99)
elif optim=='Adadelta':
    from keras.optimizers import Adadelta
    optimizer = Adadelta(rhom=0.95)
elif optim=='Adam':
    from keras.optimizers import Adam
    optimizer = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999)
elif optim=='AMSGrad': 
    from keras.optimizers import Adam
    optimizer = Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.999, amsgrad=True)
else:
    raise ValueError('Unknown optimizer: {}'.format(optim))

# %%
if num_class > 2:
    loss = "categorical_crossentropy"
else:
    loss = "binary_crossentropy"

# %%
model.compile(loss=loss,
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
earlystop = EarlyStopping(patience=patience)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', # tensorflow 2.x
                                            verbose=1, 
                                            factor=1/num_class, # 1/ class数
                                            min_lr=0.00001)

modelCheckpoint = ModelCheckpoint(filepath = ".",
                                  monitor='val_accuracy',
                                  verbose=1,
                                  save_best_only=True,
                                  save_weights_only=False, # 重みのみ保存
                                  mode='max', # val_accuracyの場合
                                  save_freq=1)

callbacks = []
if early_stop:
    callbacks += [searlystop]
    
if reduce_rl:
    callbacks += [learning_rate_reduction]
    
if checkpoint:
    callbacks += [modelCheckpoint]

if len(callbacks) == 0:
    callbacks = None
callbacks

# %%
if aug:
    history = model.fit(
        datagen.flow(x_train, y_train, batch_size=batch_size),
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        validation_data=(x_test, y_test),
        shuffle=True,
        callbacks=callbacks)
else:
    history = model.fit(
        x_train, y_train,
        batch_size=batch_size,
        initial_epoch = 0,
        epochs=epochs,
        validation_data=(x_test, y_test),
        shuffle=True,
        callbacks=callbacks)
# Out:
# Epoch 1/150
# 7/7 [==============================] - 3s 275ms/step - loss: 0.7552 - accuracy: 0.4742 - val_loss: 0.7020 - val_accuracy: 0.4286
# Epoch 2/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.7323 - accuracy: 0.5240 - val_loss: 0.7155 - val_accuracy: 0.4464
# Epoch 3/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.7527 - accuracy: 0.5040 - val_loss: 0.6934 - val_accuracy: 0.4821
# Epoch 4/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.7329 - accuracy: 0.5538 - val_loss: 0.7043 - val_accuracy: 0.4464
# Epoch 5/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.7072 - accuracy: 0.5369 - val_loss: 0.6964 - val_accuracy: 0.4643
# Epoch 6/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.7270 - accuracy: 0.4935 - val_loss: 0.6993 - val_accuracy: 0.5179
# Epoch 7/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.7394 - accuracy: 0.4854 - val_loss: 0.7107 - val_accuracy: 0.4286
# Epoch 8/150
# 7/7 [==============================] - 2s 240ms/step - loss: 0.7348 - accuracy: 0.4683 - val_loss: 0.7151 - val_accuracy: 0.4286
# Epoch 9/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.6960 - accuracy: 0.5549 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 10/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.7110 - accuracy: 0.5419 - val_loss: 0.7021 - val_accuracy: 0.5000
# Epoch 11/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.7086 - accuracy: 0.5155 - val_loss: 0.7032 - val_accuracy: 0.5000
# Epoch 12/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.7060 - accuracy: 0.5782 - val_loss: 0.6953 - val_accuracy: 0.5000
# Epoch 13/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6876 - accuracy: 0.6077 - val_loss: 0.7167 - val_accuracy: 0.4643
# Epoch 14/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.7030 - accuracy: 0.5910 - val_loss: 0.6951 - val_accuracy: 0.5357
# Epoch 15/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6927 - accuracy: 0.5538 - val_loss: 0.6952 - val_accuracy: 0.5179
# Epoch 16/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6816 - accuracy: 0.6062 - val_loss: 0.6962 - val_accuracy: 0.5536
# Epoch 17/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6761 - accuracy: 0.5914 - val_loss: 0.6943 - val_accuracy: 0.5179
# Epoch 18/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6975 - accuracy: 0.5655 - val_loss: 0.6912 - val_accuracy: 0.5536
# Epoch 19/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6824 - accuracy: 0.5984 - val_loss: 0.6986 - val_accuracy: 0.5179
# Epoch 20/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6389 - accuracy: 0.6505 - val_loss: 0.6978 - val_accuracy: 0.5000
# Epoch 21/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6891 - accuracy: 0.6151 - val_loss: 0.7051 - val_accuracy: 0.5536
# Epoch 22/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6307 - accuracy: 0.6931 - val_loss: 0.7006 - val_accuracy: 0.5179
# Epoch 23/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6980 - accuracy: 0.5655 - val_loss: 0.6927 - val_accuracy: 0.5179
# Epoch 24/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6491 - accuracy: 0.6742 - val_loss: 0.6957 - val_accuracy: 0.5357
# Epoch 25/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6396 - accuracy: 0.6560 - val_loss: 0.6872 - val_accuracy: 0.4821
# Epoch 26/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6602 - accuracy: 0.5823 - val_loss: 0.6872 - val_accuracy: 0.5357
# Epoch 27/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.6678 - accuracy: 0.6138 - val_loss: 0.6996 - val_accuracy: 0.5536
# Epoch 28/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6394 - accuracy: 0.6743 - val_loss: 0.6790 - val_accuracy: 0.5536
# Epoch 29/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.6405 - accuracy: 0.6614 - val_loss: 0.6865 - val_accuracy: 0.5357
# Epoch 30/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6425 - accuracy: 0.6191 - val_loss: 0.6824 - val_accuracy: 0.5357
# Epoch 31/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6321 - accuracy: 0.6661 - val_loss: 0.6830 - val_accuracy: 0.5536
# Epoch 32/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6209 - accuracy: 0.6708 - val_loss: 0.6959 - val_accuracy: 0.5714
# Epoch 33/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6093 - accuracy: 0.7081 - val_loss: 0.6874 - val_accuracy: 0.5357
# Epoch 34/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6218 - accuracy: 0.6775 - val_loss: 0.6784 - val_accuracy: 0.5000
# Epoch 35/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6597 - accuracy: 0.6102 - val_loss: 0.7085 - val_accuracy: 0.5000
# Epoch 36/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6401 - accuracy: 0.6384 - val_loss: 0.6835 - val_accuracy: 0.5536
# Epoch 37/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6180 - accuracy: 0.6754 - val_loss: 0.7339 - val_accuracy: 0.5179
# Epoch 38/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6148 - accuracy: 0.6795 - val_loss: 0.6803 - val_accuracy: 0.5536
# Epoch 39/150
# 7/7 [==============================] - 2s 233ms/step - loss: 0.6062 - accuracy: 0.6864 - val_loss: 0.6725 - val_accuracy: 0.5536
# Epoch 40/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.5930 - accuracy: 0.6834 - val_loss: 0.6746 - val_accuracy: 0.5893
# Epoch 41/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.5979 - accuracy: 0.6850 - val_loss: 0.6688 - val_accuracy: 0.5179
# Epoch 42/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.5739 - accuracy: 0.7524 - val_loss: 0.6877 - val_accuracy: 0.5357
# Epoch 43/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.6016 - accuracy: 0.7325 - val_loss: 0.6966 - val_accuracy: 0.5179
# Epoch 44/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.5986 - accuracy: 0.7076 - val_loss: 0.6651 - val_accuracy: 0.5714
# Epoch 45/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.5842 - accuracy: 0.7523 - val_loss: 0.7472 - val_accuracy: 0.4821
# Epoch 46/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6214 - accuracy: 0.6668 - val_loss: 0.6735 - val_accuracy: 0.6071
# Epoch 47/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.5974 - accuracy: 0.6712 - val_loss: 0.6953 - val_accuracy: 0.6071
# Epoch 48/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.6188 - accuracy: 0.6381 - val_loss: 0.7856 - val_accuracy: 0.4821
# Epoch 49/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.5767 - accuracy: 0.6550 - val_loss: 0.7041 - val_accuracy: 0.6071
# Epoch 50/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.6452 - accuracy: 0.5998 - val_loss: 0.6956 - val_accuracy: 0.5179
# Epoch 51/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.5749 - accuracy: 0.7202 - val_loss: 0.6489 - val_accuracy: 0.6250
# Epoch 52/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.5705 - accuracy: 0.7571 - val_loss: 0.6622 - val_accuracy: 0.5893
# Epoch 53/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.5711 - accuracy: 0.7509 - val_loss: 0.6505 - val_accuracy: 0.6071
# Epoch 54/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.5481 - accuracy: 0.7470 - val_loss: 0.6425 - val_accuracy: 0.6071
# Epoch 55/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.5672 - accuracy: 0.7396 - val_loss: 0.6431 - val_accuracy: 0.5714
# Epoch 56/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.5317 - accuracy: 0.7513 - val_loss: 0.7849 - val_accuracy: 0.5000
# Epoch 57/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.5420 - accuracy: 0.7192 - val_loss: 0.6653 - val_accuracy: 0.6429
# Epoch 58/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.6249 - accuracy: 0.6450 - val_loss: 0.6196 - val_accuracy: 0.6429
# Epoch 59/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.5606 - accuracy: 0.7129 - val_loss: 0.6949 - val_accuracy: 0.4821
# Epoch 60/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.4908 - accuracy: 0.7924 - val_loss: 0.6687 - val_accuracy: 0.6071
# Epoch 61/150
# 7/7 [==============================] - 2s 233ms/step - loss: 0.6071 - accuracy: 0.6769 - val_loss: 0.6780 - val_accuracy: 0.5714
# Epoch 62/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.5216 - accuracy: 0.7663 - val_loss: 0.6112 - val_accuracy: 0.7321
# Epoch 63/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.4550 - accuracy: 0.9042 - val_loss: 0.6023 - val_accuracy: 0.7321
# Epoch 64/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.4581 - accuracy: 0.8338 - val_loss: 0.6065 - val_accuracy: 0.6250
# Epoch 65/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.5030 - accuracy: 0.7365 - val_loss: 0.5997 - val_accuracy: 0.6607
# Epoch 66/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.4753 - accuracy: 0.8390 - val_loss: 0.5896 - val_accuracy: 0.7143
# Epoch 67/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.4764 - accuracy: 0.8172 - val_loss: 0.7007 - val_accuracy: 0.5357
# Epoch 68/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.4331 - accuracy: 0.8168 - val_loss: 0.5780 - val_accuracy: 0.7500
# Epoch 69/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.4187 - accuracy: 0.8732 - val_loss: 0.5625 - val_accuracy: 0.7679
# Epoch 70/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.4093 - accuracy: 0.8912 - val_loss: 0.5594 - val_accuracy: 0.7679
# Epoch 71/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.4002 - accuracy: 0.8584 - val_loss: 0.5519 - val_accuracy: 0.7321
# Epoch 72/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.3922 - accuracy: 0.8495 - val_loss: 0.5401 - val_accuracy: 0.7679
# Epoch 73/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.3604 - accuracy: 0.9135 - val_loss: 0.5660 - val_accuracy: 0.7500
# Epoch 74/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.3923 - accuracy: 0.8532 - val_loss: 0.5291 - val_accuracy: 0.7500
# Epoch 75/150
# 7/7 [==============================] - 2s 233ms/step - loss: 0.3814 - accuracy: 0.8482 - val_loss: 0.5110 - val_accuracy: 0.7679
# Epoch 76/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.3534 - accuracy: 0.8891 - val_loss: 0.5269 - val_accuracy: 0.7321
# Epoch 77/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.3682 - accuracy: 0.8636 - val_loss: 0.4852 - val_accuracy: 0.8214
# Epoch 78/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.3358 - accuracy: 0.8921 - val_loss: 0.6180 - val_accuracy: 0.6250
# Epoch 79/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.3171 - accuracy: 0.9200 - val_loss: 0.6698 - val_accuracy: 0.6250
# Epoch 80/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.4104 - accuracy: 0.8055 - val_loss: 0.6505 - val_accuracy: 0.6429
# Epoch 81/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.3500 - accuracy: 0.8837 - val_loss: 0.6117 - val_accuracy: 0.6607
# Epoch 82/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.3346 - accuracy: 0.8762 - val_loss: 0.6147 - val_accuracy: 0.6607
# Epoch 83/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.3514 - accuracy: 0.8451 - val_loss: 0.4633 - val_accuracy: 0.8214
# Epoch 84/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.3422 - accuracy: 0.8845 - val_loss: 0.4731 - val_accuracy: 0.7500
# Epoch 85/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.2939 - accuracy: 0.9118 - val_loss: 0.4189 - val_accuracy: 0.8750
# Epoch 86/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.2605 - accuracy: 0.9252 - val_loss: 0.4002 - val_accuracy: 0.8750
# Epoch 87/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.2633 - accuracy: 0.9350 - val_loss: 0.4141 - val_accuracy: 0.8571
# Epoch 88/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.2346 - accuracy: 0.9565 - val_loss: 0.5516 - val_accuracy: 0.7500
# Epoch 89/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.2142 - accuracy: 0.9485 - val_loss: 0.3799 - val_accuracy: 0.8393
# Epoch 90/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.2186 - accuracy: 0.9071 - val_loss: 0.3471 - val_accuracy: 0.9107
# Epoch 91/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.1862 - accuracy: 0.9575 - val_loss: 0.3328 - val_accuracy: 0.9107
# Epoch 92/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.1982 - accuracy: 0.9545 - val_loss: 0.3329 - val_accuracy: 0.9286
# Epoch 93/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.2068 - accuracy: 0.9664 - val_loss: 0.3376 - val_accuracy: 0.8393
# Epoch 94/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.1368 - accuracy: 0.9892 - val_loss: 0.5947 - val_accuracy: 0.7500
# Epoch 95/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.2565 - accuracy: 0.8934 - val_loss: 0.7079 - val_accuracy: 0.6250
# Epoch 96/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.2384 - accuracy: 0.9101 - val_loss: 0.2851 - val_accuracy: 0.9286
# Epoch 97/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.1439 - accuracy: 0.9741 - val_loss: 0.2721 - val_accuracy: 0.9107
# Epoch 98/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.1453 - accuracy: 0.9668 - val_loss: 0.3531 - val_accuracy: 0.8393
# Epoch 99/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.1289 - accuracy: 0.9758 - val_loss: 0.2470 - val_accuracy: 0.9464
# Epoch 100/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0982 - accuracy: 0.9945 - val_loss: 0.2550 - val_accuracy: 0.8929
# Epoch 101/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.1409 - accuracy: 0.9619 - val_loss: 0.2865 - val_accuracy: 0.9286
# Epoch 102/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.1274 - accuracy: 0.9918 - val_loss: 0.2833 - val_accuracy: 0.8750
# Epoch 103/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.1162 - accuracy: 0.9561 - val_loss: 0.3230 - val_accuracy: 0.8750
# Epoch 104/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0793 - accuracy: 0.9929 - val_loss: 0.2054 - val_accuracy: 0.9464
# Epoch 105/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0785 - accuracy: 0.9864 - val_loss: 0.3363 - val_accuracy: 0.8750
# Epoch 106/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.1448 - accuracy: 0.9422 - val_loss: 0.1835 - val_accuracy: 0.9286
# Epoch 107/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0820 - accuracy: 0.9846 - val_loss: 0.3716 - val_accuracy: 0.8214
# Epoch 108/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.1053 - accuracy: 0.9709 - val_loss: 0.2265 - val_accuracy: 0.9107
# Epoch 109/150
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 0.2469 - val_accuracy: 0.8750
# Epoch 110/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0952 - accuracy: 0.9702 - val_loss: 0.2166 - val_accuracy: 0.9286
# Epoch 111/150
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0752 - accuracy: 0.9952 - val_loss: 0.1545 - val_accuracy: 0.9464
# Epoch 112/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 0.9107
# Epoch 113/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9107
# Epoch 114/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0430 - accuracy: 0.9882 - val_loss: 0.1296 - val_accuracy: 0.9464
# Epoch 115/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0346 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 0.9107
# Epoch 116/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0280 - accuracy: 0.9952 - val_loss: 0.1268 - val_accuracy: 0.9286
# Epoch 117/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.9107
# Epoch 118/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0315 - accuracy: 0.9893 - val_loss: 0.1209 - val_accuracy: 0.9643
# Epoch 119/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.1285 - val_accuracy: 0.9464
# Epoch 120/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0241 - accuracy: 0.9982 - val_loss: 0.2185 - val_accuracy: 0.8929
# Epoch 121/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0487 - accuracy: 0.9884 - val_loss: 0.1278 - val_accuracy: 0.9821
# Epoch 122/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.1587 - val_accuracy: 0.9107
# Epoch 123/150
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0259 - accuracy: 0.9893 - val_loss: 0.1062 - val_accuracy: 0.9464
# Epoch 124/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0187 - accuracy: 0.9965 - val_loss: 0.1062 - val_accuracy: 0.9464
# Epoch 125/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9286
# Epoch 126/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 0.9464
# Epoch 127/150
# 7/7 [==============================] - 2s 240ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9464
# Epoch 128/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.1159 - val_accuracy: 0.9286
# Epoch 129/150
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9286
# Epoch 130/150
# 7/7 [==============================] - 2s 233ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 0.9464
# Epoch 131/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9464
# Epoch 132/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 0.9464
# Epoch 133/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9464
# Epoch 134/150
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.1080 - val_accuracy: 0.9464
# Epoch 135/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9464
# Epoch 136/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9464
# Epoch 137/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9464
# Epoch 138/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0826 - val_accuracy: 0.9464
# Epoch 139/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9464
# Epoch 140/150
# 7/7 [==============================] - 2s 235ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 0.9464
# Epoch 141/150
# 7/7 [==============================] - 2s 234ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.1593 - val_accuracy: 0.9107
# Epoch 142/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9643
# Epoch 143/150
# 7/7 [==============================] - 2s 239ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 0.9464
# Epoch 144/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 0.9464
# Epoch 145/150
# 7/7 [==============================] - 2s 236ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.1119 - val_accuracy: 0.9464
# Epoch 146/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9643
# Epoch 147/150
# 7/7 [==============================] - 2s 238ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0771 - val_accuracy: 0.9643
# Epoch 148/150
# 7/7 [==============================] - 2s 237ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9464
# Epoch 149/150
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9464
# Epoch 150/150
# 7/7 [==============================] - 2s 232ms/step - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0877 - val_accuracy: 0.9464

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

### Plot accuracy & loss
import matplotlib.pyplot as plt 

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)

#plot accuracy
plt.plot(epochs, acc, label = "Training acc" )
plt.plot(epochs, val_acc, label = "Validation acc")
plt.title("Training and Validation accuracy")
plt.legend()
plt.show()

#plot loss
plt.plot(epochs, loss,  label = "Training loss" )
plt.plot(epochs, val_loss, label = "Validation loss")
plt.title("Training and Validation loss")
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 64ms/step - loss: 0.0877 - accuracy: 0.9464
# Test loss: 0.08770900219678879
# Test accuracy: 0.9464285969734192

# %%
model.save_weights('grad_vgg16_weight_DAGM_C1.h5')

# %%
K.set_learning_phase(1) #set learning phase

def Grad_Cam(input_model, pic_array, layer_name):
  X = np.expand_dims(pic_array, axis=0)
  preprocessed_input = X.astype('float32') / 255.0    

  grad_model = models.Model([input_model.inputs], [input_model.get_layer('block5_conv3').output, input_model.output])

  with tf.GradientTape() as tape:
    conv_outputs, predictions = grad_model(preprocessed_input)
    class_idx = np.argmax(predictions[0])
    loss = predictions[:, class_idx]

  output = conv_outputs[0]
  grads = tape.gradient(loss, conv_outputs)[0]

  gate_f = tf.cast(output > 0, 'float32')
  gate_r = tf.cast(grads > 0, 'float32')

  guided_grads = gate_f * gate_r * grads

  # 重みを平均化して、レイヤーの出力に乗じる
  weights = np.mean(guided_grads, axis=(0, 1))
  cam = np.dot(output, weights)

  # 画像化してヒートマップにして合成
  cam = cv2.resize(cam, (224, 224), cv2.INTER_LINEAR) 
  cam = np.maximum(cam, 0) 
  cam = cam / cam.max()

  jetcam = cv2.applyColorMap(np.uint8(255 * cam), cv2.COLORMAP_JET)  # モノクロ画像に疑似的に色をつける
  jetcam = cv2.cvtColor(jetcam, cv2.COLOR_BGR2RGB)  # 色をRGBに変換
  jetcam = (np.float32(jetcam) + pic / 2)   # もとの画像に合成
  return jetcam
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:434: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
pic_array = img_to_array(load_img('/content/drive/MyDrive/image_demo/ng/10.png', target_size=(224, 224)))
pic = pic_array.reshape((1,) + pic_array.shape)
array_to_img(pic_array)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FBA51800950>

# %%
model.load_weights('/content/grad_vgg16_weight_DAGM_C1.h5')

picture = Grad_Cam(model, pic_array, 'block5_conv3')
picture = picture[0,:,:,]
array_to_img(picture)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FBCA6446810>

# %%
model.save('/content/drive/MyDrive/image_classifier_demo.h5')
